# %%
"""Q1: Extract the video URL of the first five videos:
python

from pytube import YouTube

def get_video_urls(query, num_videos=5):
    results = YouTube.search(query, max_results=num_videos)
    video_urls = [f"https://www.youtube.com/watch?v={video.video_id}" for video in results]
    return video_urls

# Example usage
query = "Python programming tutorial"
video_urls = get_video_urls(query)
print(video_urls)
Q2: Extract the URL of the video thumbnails of the first five videos:
python

from pytube import YouTube

def get_thumbnail_urls(query, num_videos=5):
    results = YouTube.search(query, max_results=num_videos)
    thumbnail_urls = [video.thumbnail_url for video in results]
    return thumbnail_urls

# Example usage
query = "Python programming tutorial"
thumbnail_urls = get_thumbnail_urls(query)
print(thumbnail_urls)
Q3: Extract the title of the first five videos:
python
Copy code
from pytube import YouTube

def get_video_titles(query, num_videos=5):
    results = YouTube.search(query, max_results=num_videos)
    video_titles = [video.title for video in results]
    return video_titles

# Example usage
query = "Python programming tutorial"
video_titles = get_video_titles(query)
print(video_titles)
Q4: Extract the number of views of the first five videos:
python

from pytube import YouTube

def get_video_views(query, num_videos=5):
    results = YouTube.search(query, max_results=num_videos)
    video_views = [video.views for video in results]
    return video_views

# Example usage
query = "Python programming tutorial"
video_views = get_video_views(query)
print(video_views)
Q5: Extract the time of posting of the video for the first five videos:
python

from pytube import YouTube

def get_video_publish_time(query, num_videos=5):
    results = YouTube.search(query, max_results=num_videos)
    publish_times = [video.publish_time for video in results]
    return publish_times

# Example usage
query = "Python programming tutorial"
publish_times = get_video_publish_time(query)
print(publish_times)
